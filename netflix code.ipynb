# %%
#setup
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from networkx.algorithms import community
# read edge list
g = nx.read_edgelist("project.txt")
ug = nx.to_undirected(g)
# print basic info (is the graph ok?)
print(nx.info(ug))
# Out:
# Name:
# Type: GraphView
# Number of nodes: 159
# Number of edges: 178
# Average degree:   2.2390

# %%
#setup
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from networkx.algorithms import community
# read edge list
g = nx.read_edgelist("project.txt")
ug = nx.to_undirected(g)
# print basic info (is the graph ok?)
print(nx.info(ug))
nx.draw(ug, with_labels=True)
# Out:
# Name:
# Type: GraphView
# Number of nodes: 159
# Number of edges: 178
# Average degree:   2.2390

# %%
#setup
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from networkx.algorithms import community
# read edge list
g = nx.read_edgelist("project.txt")
ug = nx.to_undirected(g)
# print basic info (is the graph ok?)
print(nx.info(ug)
options = {'node_color': 'blue',
    'node_size': 50,
    'line_color': 'black',
    'linewidths': 0,
    'width': 0.1}
    
nx.draw(ug, **options)
plt.savefig ("simple_graph.png")
# Out:
#   File "<ipython-input-3-16c83e7b57df>", line 11
#     options = {'node_color': 'blue',
#           ^
# SyntaxError: invalid syntax

# %%
#setup
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from networkx.algorithms import community
# read edge list
g = nx.read_edgelist("Edgelist2.txt")
ug = nx.to_undirected(g)
# print basic info (is the graph ok?)
print(nx.info(ug))
# taken from SNAP Tutorial
def plot_degree_distribution (wiki) :
    degs = {}
    for n in wiki.nodes () :
        deg = wiki.degree ( n )
        
        
        if deg not in degs :
            degs [ deg ] = 0
        
        degs [ deg ] += 1
    items = sorted ( degs.items () )
            
    fig = plt.figure ()
    ax = fig.add_subplot (111)
    ax.plot ([ k for (k , v ) in items ] , [ v for (k ,v ) in items ])
    ax.set_xscale('log')
    ax.set_yscale('log')
    plt.title("Degree Distribution")
    fig.savefig ("degree_distribution.png")
    
            
plot_degree_distribution(ug)
# Out:
# Name:
# Type: GraphView
# Number of nodes: 147
# Number of edges: 98
# Average degree:   1.3333

# %%
#setup
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from networkx.algorithms import community
# read edge list
g = nx.read_edgelist("project.txt")
ug = nx.to_undirected(g)
# print basic info (is the graph ok?)
print(nx.info(ug))
# set color and size of nodes as per degree of each node


d = [] # create a set
for n in ug.nodes():
    d.append(ug.degree(n))
    
ec = [] # create a set
for e in ug.edges():
    if(ug.degree(e[0]) > ug.degree(e[1])):
        ec.append(ug.degree(e[0]))
    else:
        ec.append(ug.degree(e[1]))
    
pos = nx.spring_layout(ug, iterations=200)

factor = 200 # to change the size of nodes with respect to their degree


# choose color plate from https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
# example: viridis
nx.draw(ug, pos,
        edge_color = ec,  edge_cmap=plt.cm.plasma,  # edge color
        node_color = d, cmap=plt.cm.plasma, # node color
        node_size=[x * factor for x in d]) # node sizse
# Out:
# Name:
# Type: GraphView
# Number of nodes: 159
# Number of edges: 178
# Average degree:   2.2390
